# %%
import numpy as np
import pandas as pd
import matplotlib.pylab as plt
import seaborn as sns

# %%
df = pd.read_excel('/Users/evahuang/Desktop/Unemployment.xlsx')

# %%
df.head()
# Out:
#    Year         AL         AK         AZ        AR         CA        CO  \
# 0  2008   6.976119   8.810345   8.106667  6.197333   8.532759  4.614062
# 1  2009  13.171642   9.893103  13.093333  8.632000  12.232759  6.509375
# 2  2010  12.349254  10.396552  13.053333  9.068000  13.806897  8.589063
# 3  2011  11.216418  10.737931  12.233333  9.281333  13.432759  8.253125
# 4  2012   9.253731  10.589655  11.220000  8.509333  12.143103  7.864062
#
#        CT        DE    DC  ...         TN        TX        UT        VT  \
# 0  5.3625  5.333333   5.8  ...   7.806316  4.550000  4.051724  4.978571
# 1  7.8125  8.200000  10.1  ...  12.438947  7.290157  7.772414  6.964286
# 2  8.9250  8.566667   9.4  ...  11.308421  7.971654  8.475862  6.771429
# 3  8.6125  7.733333  10.2  ...  10.451579  7.499606  7.531034  6.114286
# 4  8.2000  7.366667   9.0  ...   9.182105  6.455906  6.293103  5.564286
#
#          VA         WA        WV        WI        WY         PY
# 0  4.830827   6.530769  4.976364  5.322222  4.039130  13.301316
# 1  8.057143   9.925641  8.861818  9.055556  7.286957  17.532895
# 2  8.476692  10.743590  9.740000  9.388889  6.160870  19.061538
# 3  7.746617  10.335897  8.985455  8.463889  5.621739  18.593590
# 4  7.108271   9.533333  8.443636  7.658333  5.186957  17.121795
#
# [5 rows x 53 columns]

# %%
fig = plt.figure(figsize=(10,6))
plt.title('Unemployment Rates for States')
plt.xlabel('Year')
plt.ylabel('Rate(%)')
plt.plot(df['Year'], 
         df['AL'], 
         linestyle = '-', 
         linewidth = 2, 
         color = 'steelblue', 
         marker = 'o', 
         markersize = 6, 
         markeredgecolor='black', 
         markerfacecolor='brown',
         label='AL'
        )

plt.plot(df['Year'], 
         df['AK'], 
         linestyle = '-', 
         linewidth = 2, 
         color = 'green', 
         marker = 'o', 
         markersize = 6, 
         markeredgecolor='black', 
         markerfacecolor='brown',
        label='AK'
        )

plt.plot(df['Year'], 
         df['AZ'], 
         linestyle = '-', 
         linewidth = 2, 
         color = 'red', 
         marker = 'o', 
         markersize = 6, 
         markeredgecolor='black', 
         markerfacecolor='brown',
        label='AZ')

plt.plot(df['Year'], 
         df['AR'], 
         linestyle = '-', 
         linewidth = 2, 
         color = 'rosybrown', 
         marker = 'o', 
         markersize = 6, 
         markeredgecolor='black', 
         markerfacecolor='brown',
        label='AR')

plt.plot(df['Year'], 
         df['CA'], 
         linestyle = '-', 
         linewidth = 2, 
         color = 'steelblue', 
         marker = 'o', 
         markersize = 6, 
         markeredgecolor='black', 
         markerfacecolor='brown',
        label='CA')

plt.plot(df['Year'], 
         df['CO'], 
         linestyle = '-', 
         linewidth = 2, 
         color = 'purple', 
         marker = 'o', 
         markersize = 6, 
         markeredgecolor='black', 
         markerfacecolor='brown',
        label='CO')

plt.plot(df['Year'], 
         df['CT'], 
         linestyle = '-', 
         linewidth = 2, 
         color = 'springgreen', 
         marker = 'o', 
         markersize = 6, 
         markeredgecolor='black', 
         markerfacecolor='brown',
        label='CT')

plt.plot(df['Year'], 
         df['DE'], 
         linestyle = '-', 
         linewidth = 2, 
         color = 'yellow', 
         marker = 'o', 
         markersize = 6, 
         markeredgecolor='black', 
         markerfacecolor='brown',
        label='DE')

plt.plot(df['Year'], 
         df['DC'], 
         linestyle = '-', 
         linewidth = 2, 
         color = 'salmon', 
         marker = 'o', 
         markersize = 6, 
         markeredgecolor='black', 
         markerfacecolor='brown',
        label='DC')

plt.plot(df['Year'], 
         df['FL'], 
         linestyle = '-', 
         linewidth = 2, 
         color = 'wheat', 
         marker = 'o', 
         markersize = 6, 
         markeredgecolor='black', 
         markerfacecolor='brown',
        label='FL')

plt.plot(df['Year'], 
         df['GA'], 
         linestyle = '-', 
         linewidth = 2, 
         color = 'thistle', 
         marker = 'o', 
         markersize = 6, 
         markeredgecolor='black', 
         markerfacecolor='brown',
        label='GA')

plt.plot(df['Year'], 
         df['HI'], 
         linestyle = '-', 
         linewidth = 2, 
         color = 'tomato', 
         marker = 'o', 
         markersize = 6, 
         markeredgecolor='black', 
         markerfacecolor='brown',
        label='HI')

plt.plot(df['Year'], 
         df['ID'], 
         linestyle = '-', 
         linewidth = 2, 
         color = 'orange', 
         marker = 'o', 
         markersize = 6, 
         markeredgecolor='black', 
         markerfacecolor='brown',
        label='ID')

plt.plot(df['Year'], 
         df['IL'], 
         linestyle = '-', 
         linewidth = 2, 
         color = 'gray', 
         marker = 'o', 
         markersize = 6, 
         markeredgecolor='black', 
         markerfacecolor='brown',
        label='IL')

plt.legend()
